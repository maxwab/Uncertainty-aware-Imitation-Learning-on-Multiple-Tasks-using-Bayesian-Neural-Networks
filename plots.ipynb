# %%
import matplotlib.pyplot as plt
% matplotlib inline
plt.style.use('ggplot')

from Plots import visualize_learner, plot_uncertainty_vs_tasks
from Housekeeping import *

# %%
all_task_configurations = [
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'BBB', CONTEXT_CODE_KEY: '0', WINDOW_SIZE_KEY: '1', PARTIAL_OBSERVABILITY_KEY: 'True'},
     ]

plt.rcParams["figure.figsize"] = (40, 20)
 
font = {'size': 25}
plt.rc('font', **font)
 
plt.rcParams["grid.alpha"] = 1
plt.rcParams["grid.color"] = "#cccccc"

visualize_learner(all_task_configurations)

# %%
all_task_configurations = [
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[10.0]', WINDOW_SIZE_KEY: '1', PARTIAL_OBSERVABILITY_KEY: 'True'},
     ]

plt.rcParams["figure.figsize"] = (40, 20)
 
font = {'size': 25}
plt.rc('font', **font)
 
plt.rcParams["grid.alpha"] = 1
plt.rcParams["grid.color"] = "#cccccc"

plot_uncertainty_vs_tasks(all_task_configurations)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-edd8d55192cf> in <module>()
#      11 plt.rcParams["grid.color"] = "#cccccc"
#      12
# ---> 13 plot_uncertainty_vs_tasks(all_task_configurations)
#
# ~/Projects/Task_Agnostic_Online_Multitask_Imitation_Learning/Plots.py in plot_uncertainty_vs_tasks(all_task_configurations)
#      80         file_to_load_data_from = './' + configuration[EXPERIMENT_ID_KEY] + '/' + LOGS_DIRECTORY + configuration[CONTEXTS_KEY] + '_' + configuration[WINDOW_SIZE_KEY] + '_' + configuration[PARTIAL_OBSERVABILITY_KEY] + '_' + configuration[BEHAVIORAL_CONTROLLER_KEY] + '_' + configuration[TARGET_CONTROLLER_KEY] + '.pkl'
#      81         configuration_label = configuration[CONTEXTS_KEY] + '_' + configuration[WINDOW_SIZE_KEY] + '_' + configuration[PARTIAL_OBSERVABILITY_KEY] + '_' + configuration[BEHAVIORAL_CONTROLLER_KEY] + '_' + configuration[TARGET_CONTROLLER_KEY]
# ---> 82         with open(file_to_load_data_from, 'rb') as f:
#      83             loaded_data = pickle.load(f)
#      84         all_tasks = list(loaded_data.keys())
#
# FileNotFoundError: [Errno 2] No such file or directory: './sliding_block/logs/[10.0]_1_True_GP_LQR.pkl'
