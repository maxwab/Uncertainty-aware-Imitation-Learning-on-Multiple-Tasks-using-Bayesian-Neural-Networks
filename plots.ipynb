# %%
from Plots import plot_uncertainty_vs_tasks
from Housekeeping import *

# %%
all_task_configurations = [
    {EXPERIMENT_ID_KEY: 'sliding_block', CONTROLLER_KEY: 'gp_controller', CONTEXTS_KEY: '[80.0]', WINDOW_SIZE_KEY: '1', PARTIAL_OBSERVABILITY_KEY: 'True'},
     ]

plot_uncertainty_vs_tasks(all_task_configurations)
