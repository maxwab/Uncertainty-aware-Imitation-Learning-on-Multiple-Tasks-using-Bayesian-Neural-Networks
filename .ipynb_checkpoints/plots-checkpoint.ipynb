# %%
import matplotlib.pyplot as plt
% matplotlib inline
plt.style.use('ggplot')

from Plots import visualize_learner, plot_uncertainty_vs_tasks
from Housekeeping import *

# %%
all_task_configurations = [
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', CONTEXT_CODE_KEY: '3', WINDOW_SIZE_KEY: '1', PARTIAL_OBSERVABILITY_KEY: 'True'},
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', CONTEXT_CODE_KEY: '4', WINDOW_SIZE_KEY: '1', PARTIAL_OBSERVABILITY_KEY: 'True'},
     ]

plt.rcParams["figure.figsize"] = (40, 20)
 
font = {'size': 25}
plt.rc('font', **font)
 
plt.rcParams["grid.alpha"] = 1
plt.rcParams["grid.color"] = "#cccccc"

visualize_learner(all_task_configurations)

# %%
all_task_configurations = [
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', CONTEXT_CODE_KEY: '0', WINDOW_SIZE_KEY: '1', PARTIAL_OBSERVABILITY_KEY: 'True'},
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'BBB', CONTEXT_CODE_KEY: '0', WINDOW_SIZE_KEY: '1', PARTIAL_OBSERVABILITY_KEY: 'True'},
     ]

plt.rcParams["figure.figsize"] = (40, 20)
 
font = {'size': 25}
plt.rc('font', **font)
 
plt.rcParams["grid.alpha"] = 1
plt.rcParams["grid.color"] = "#cccccc"

visualize_learner(all_task_configurations)

# %%
all_task_configurations = [
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[10.0]', WINDOW_SIZE_KEY: '1', PARTIAL_OBSERVABILITY_KEY: 'True'},
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[10.0]', WINDOW_SIZE_KEY: '2', PARTIAL_OBSERVABILITY_KEY: 'True'},
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[10.0]', WINDOW_SIZE_KEY: '1', PARTIAL_OBSERVABILITY_KEY: 'False'},
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[10.0]', WINDOW_SIZE_KEY: '2', PARTIAL_OBSERVABILITY_KEY: 'False'},
     ]

plt.rcParams["figure.figsize"] = (40, 20)
 
font = {'size': 25}
plt.rc('font', **font)
 
plt.rcParams["grid.alpha"] = 1
plt.rcParams["grid.color"] = "#cccccc"

plot_uncertainty_vs_tasks(all_task_configurations)

# %%
all_task_configurations = [
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[25.0]', WINDOW_SIZE_KEY: '1', PARTIAL_OBSERVABILITY_KEY: 'True'},
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[25.0]', WINDOW_SIZE_KEY: '2', PARTIAL_OBSERVABILITY_KEY: 'True'},
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[25.0]', WINDOW_SIZE_KEY: '1', PARTIAL_OBSERVABILITY_KEY: 'False'},
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[25.0]', WINDOW_SIZE_KEY: '2', PARTIAL_OBSERVABILITY_KEY: 'False'},
     ]

plt.rcParams["figure.figsize"] = (40, 20)
 
font = {'size': 25}
plt.rc('font', **font)
 
plt.rcParams["grid.alpha"] = 1
plt.rcParams["grid.color"] = "#cccccc"

plot_uncertainty_vs_tasks(all_task_configurations)

# %%
all_task_configurations = [
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[10.0]', WINDOW_SIZE_KEY: '1', PARTIAL_OBSERVABILITY_KEY: 'True'},
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[25.0]', WINDOW_SIZE_KEY: '1', PARTIAL_OBSERVABILITY_KEY: 'True'},
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[50.0]', WINDOW_SIZE_KEY: '1', PARTIAL_OBSERVABILITY_KEY: 'True'},
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[65.0]', WINDOW_SIZE_KEY: '1', PARTIAL_OBSERVABILITY_KEY: 'True'},
    #{EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[80.0]', WINDOW_SIZE_KEY: '1', PARTIAL_OBSERVABILITY_KEY: 'True'},
     ]

plt.rcParams["figure.figsize"] = (40, 20)
 
font = {'size': 25}
plt.rc('font', **font)
 
plt.rcParams["grid.alpha"] = 1
plt.rcParams["grid.color"] = "#cccccc"

plot_uncertainty_vs_tasks(all_task_configurations)

# %%
all_task_configurations = [
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[10.0]', WINDOW_SIZE_KEY: '2', PARTIAL_OBSERVABILITY_KEY: 'True'},
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[25.0]', WINDOW_SIZE_KEY: '2', PARTIAL_OBSERVABILITY_KEY: 'True'},
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[50.0]', WINDOW_SIZE_KEY: '2', PARTIAL_OBSERVABILITY_KEY: 'True'},
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[65.0]', WINDOW_SIZE_KEY: '2', PARTIAL_OBSERVABILITY_KEY: 'True'},
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[80.0]', WINDOW_SIZE_KEY: '2', PARTIAL_OBSERVABILITY_KEY: 'True'},
     ]

plt.rcParams["figure.figsize"] = (40, 20)
 
font = {'size': 25}
plt.rc('font', **font)
 
plt.rcParams["grid.alpha"] = 1
plt.rcParams["grid.color"] = "#cccccc"

plot_uncertainty_vs_tasks(all_task_configurations)

# %%
all_task_configurations = [
    #{EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[10.0]', WINDOW_SIZE_KEY: '1', PARTIAL_OBSERVABILITY_KEY: 'False'},
    #{EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[25.0]', WINDOW_SIZE_KEY: '1', PARTIAL_OBSERVABILITY_KEY: 'False'},
    #{EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[50.0]', WINDOW_SIZE_KEY: '1', PARTIAL_OBSERVABILITY_KEY: 'False'},
    #{EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[65.0]', WINDOW_SIZE_KEY: '1', PARTIAL_OBSERVABILITY_KEY: 'False'},
    #{EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[80.0]', WINDOW_SIZE_KEY: '1', PARTIAL_OBSERVABILITY_KEY: 'False'},
     ]

plt.rcParams["figure.figsize"] = (40, 20)
 
font = {'size': 25}
plt.rc('font', **font)
 
plt.rcParams["grid.alpha"] = 1
plt.rcParams["grid.color"] = "#cccccc"

plot_uncertainty_vs_tasks(all_task_configurations)

# %%
all_task_configurations = [
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[10.0]', WINDOW_SIZE_KEY: '2', PARTIAL_OBSERVABILITY_KEY: 'False'},
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[25.0]', WINDOW_SIZE_KEY: '2', PARTIAL_OBSERVABILITY_KEY: 'False'},
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[50.0]', WINDOW_SIZE_KEY: '2', PARTIAL_OBSERVABILITY_KEY: 'False'},
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[65.0]', WINDOW_SIZE_KEY: '2', PARTIAL_OBSERVABILITY_KEY: 'False'},
    {EXPERIMENT_ID_KEY: 'sliding_block', BEHAVIORAL_CONTROLLER_KEY: 'GP', TARGET_CONTROLLER_KEY: 'LQR', CONTEXTS_KEY: '[80.0]', WINDOW_SIZE_KEY: '2', PARTIAL_OBSERVABILITY_KEY: 'False'},
     ]

plt.rcParams["figure.figsize"] = (40, 20)
 
font = {'size': 25}
plt.rc('font', **font)
 
plt.rcParams["grid.alpha"] = 1
plt.rcParams["grid.color"] = "#cccccc"

plot_uncertainty_vs_tasks(all_task_configurations)
